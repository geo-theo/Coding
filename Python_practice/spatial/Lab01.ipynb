# %% [markdown]
# # Week 2, Lab \#1
#
# *January 21, 2026*

# %% [markdown]
# ## Problem 1.1: Unit Conversion
#
# Here is a sequence of temperatures in degrees Kelvin.

# %%
import numpy as np
np.random.seed(100)

temps_k = np.random.randint(240, 300, size = 10).tolist()
temps_k
# Out:
# [248, 264, 243, 279, 263, 255, 288, 250, 270, 292]

# %% [markdown]
# **Write Python code that converts the *third* (3rd) temperature in this list from degrees Kelvin to degrees Fahrenheit.** Below is an equation describing how to convert a temperature from degrees Kelvin (deg K) to degrees Fahrenheit (deg F).
#
# $$
# [\text{deg F}] = \left([\text{deg K}]\times \frac{9}{5}\right) - 459.67
# $$

# %% [markdown]
# #### *Problem 1.1 solution:*

# %%
# save third element in list as a new variable
third_temp_k = temps_k[2]

# convert from kelvin to fahrenheit using formula
third_temp_f = (third_temp_k * (9/5)) - 459.67
print(third_temp_f)

# print answer
print(f"The third temperature in the list ({third_temp_k} degrees Kelvin) is {third_temp_f} degrees Fahrenheit.")
# Out:
# -22.269999999999982
# The third temperature in the list (243 degrees Kelvin) is -22.269999999999982 degrees Fahrenheit.

# %% [markdown]
# ---
#
# ## Problem 1.2: Order of Operations
#
# In class we practiced converting from Degrees-Minutes-Seconds to decimal degrees. Now we'll do the reverse!
#
# - **Write Python code that expresses the following latitude value (below) in Degrees, Minutes, Seconds.**
# - The answer has 3 parts: Degrees, Minutes, Seconds. **You must store these 3 values, in order, in a Python list.**

# %% [markdown]
# **Write Python code that expresses the following latitude value (below) in Degrees, Minutes, Seconds.**

# %%
lat = 61.216667

# %% [markdown]
# #### *Problem 1.2 solution:*

# %%
# convert floating point degree number to integer number, making sure to round down to nearest integer using int()
degrees = int(lat)

# isolate decimal (which represents minutes + seconds), multiply by 60 for minutes
decimal_min_sec = lat % 1
minutes = decimal_min_sec * 60
# isolate decimal again on minutes float, and multiply by 60 for seconds
decimal_sec = (minutes % 1)
seconds = decimal_sec * 60

# save three numbers into new list
lat_list = [int(degrees), int(minutes), seconds]
lat_list

# print answer
print("The latitude value in Degrees/Min/Sec is " + str(lat_list[0]) + " degrees, " + str(lat_list[1]) + " minutes, and " + str(lat_list[2]) + " seconds.")
# Out:
# The latitude value in Degrees/Min/Sec is 61 degrees, 13 minutes, and 0.0012000000037915015 seconds.

# %% [markdown]
# ---
#
# ## Interlude: String Formatting
#
# When you have two or more strings that you want to combine into a single Python string, you can use the `+` operator to combine them:

# %%
"Just" + "like" + "this"
# Out:
# 'Justlikethis'

# %% [markdown]
# But as the above example shows, you have to be careful to add whitespace (or not) in the correct places.
#
# A better way to do build up a complex string is to use Python's *string formatting* syntax. Here are a couple of examples.

# %%
# Some variable assigned to a string
compliment = 'good'

# Notice the lower-case f at the beginning (outside) of this string
f"Hello there, my {compliment} chum!"
# Out:
# 'Hello there, my good chum!'

# %%
color = 'brown'
flavor = 'shrimpy'

f"Nothing like mom's home-made {color} stew; it's so {flavor}!"
# Out:
# "Nothing like mom's home-made brown stew; it's so shrimpy!"

# %% [markdown]
# With string formatting, you can put any Python expression inside the curly braces. In the two examples above, we just wrote variable names...

# %%
temperature = 298.5

f'The temperature is {round(temperature - 273.15, 1)} deg C outside!'
# Out:
# 'The temperature is 25.4 deg C outside!'

# %% [markdown]
# It's also possible to format a Python string that *doesn't* have the lower-case f in front (e.g., a regular string that was already defined elsewhere):

# %%
statement = "the sky is {color}"

statement.format(color = 'yellow')
# Out:
# 'the sky is yellow'

# %% [markdown]
# ---
#
# ## Problem 1.3: String Formatting
#
# **Using string formatting,** write Python code that produces a string that looks like the one below, **but with the correct Degrees, Minutes, Seconds from Problem 1.2.**
#
# ```
# Anchorage, AK: 46 deg 51 min 45 sec N
# ```

# %% [markdown]
# #### *Problem 1.3 solution:*

# %%
print(f"Anchorage, AK: {lat_list[0]} deg {lat_list[1]} min {round(lat_list[2], 5)} sec N")
# Out:
# Anchorage, AK: 61 deg 13 min 0.0012 sec N

# %% [markdown]
# ---
#
# ## Problem 1.4: Writing a Loop
#
# Let's revisit Problem 1.1. We need a more efficient way to convert *all* the temperatures in `temps_k` (Problem 1.1) to degrees Fahrenheit. **You can simply `print()` the converted temperature to the screen.**
#
# **Write a `for` loop to accomplish this.**

# %% [markdown]
# #### *Problem 1.4 solution:*

# %%
# for each temperature in list, apply formula and print temperature conversion
for temp in temps_k:
    temp_f = (temp * (9/5)) - 459.67
    print(str(temp)+ " Degrees K ---> " + str(temp_f) + " Degrees F")
# Out:
# 248 Degrees K ---> -13.269999999999982 Degrees F
# 264 Degrees K ---> 15.529999999999973 Degrees F
# 243 Degrees K ---> -22.269999999999982 Degrees F
# 279 Degrees K ---> 42.52999999999997 Degrees F
# 263 Degrees K ---> 13.730000000000018 Degrees F
# 255 Degrees K ---> -0.6700000000000159 Degrees F
# 288 Degrees K ---> 58.72999999999996 Degrees F
# 250 Degrees K ---> -9.670000000000016 Degrees F
# 270 Degrees K ---> 26.329999999999984 Degrees F
# 292 Degrees K ---> 65.93 Degrees F

# %% [markdown]
# ---
#
# ## Problem 1.5
#
# **NOTE: You may find this one difficult to complete until we discuss Python functions in detail on Thursday.**
#
# 1. Write a Python function that performs the Kelvin-to-Fahrenheit conversion from Problem 1.1 This function should accept a single input argument (numeric value) and return a single output (numeric value).
# 2. Copy the `for` loop you wrote for Problem 1.4 to a new code block, below.
# 3. Change this `for` loop so that, instead of doing the unit conversion in the body of the `for` loop, you call the function you wrote in each step. You should still `print()` the result to the screen.

# %% [markdown]
# #### *Problem 1.5 solution:*

# %%
# Define function that takes kelvin temp as input parameter, and performs conversion formula
def k_to_f(temp_k):
    temp_f = (temp_k * (9/5)) - 459.67
    return temp_f

# %%
# Execute function
for temp in temps_k:
    temp_f = k_to_f(temp)
    print(str(temp)+ " Degrees K ---> " + str(temp_f) + " Degrees F")
# Out:
# 248 Degrees K ---> -13.269999999999982 Degrees F
# 264 Degrees K ---> 15.529999999999973 Degrees F
# 243 Degrees K ---> -22.269999999999982 Degrees F
# 279 Degrees K ---> 42.52999999999997 Degrees F
# 263 Degrees K ---> 13.730000000000018 Degrees F
# 255 Degrees K ---> -0.6700000000000159 Degrees F
# 288 Degrees K ---> 58.72999999999996 Degrees F
# 250 Degrees K ---> -9.670000000000016 Degrees F
# 270 Degrees K ---> 26.329999999999984 Degrees F
# 292 Degrees K ---> 65.93 Degrees F

# %% [markdown]
# ---
#
# ## Extra Challenges (Optional)
#
# If you'd like to challenge yourself, try these extra challenges. No extra credit can be awarded, but feel free to include the solutions in your submitted Lab notebook, so they're all in one place.
#
# 1. Starting from your Problem 1.4 solution, change the loop so that it prints a string-formatted statement about each temperature.
# 2. Starting from your Problem 1.4 solution, change the loop so that it *changes* the temperature value in the `temps_k` list.

# %% [markdown]
# #### *Extra Challenge 1 solution:*

# %%
# for each temperature calculation. print a string-formatted statement
for temp in temps_k:
    temp_f = (temp * (9/5)) - 459.67
    print(f"The temperature {temp} Degrees Kelvin converts to {temp_f} Degrees Fahrenheit")
# Out:
# The temperature 248 Degrees Kelvin converts to -13.269999999999982 Degrees Fahrenheit
# The temperature 264 Degrees Kelvin converts to 15.529999999999973 Degrees Fahrenheit
# The temperature 243 Degrees Kelvin converts to -22.269999999999982 Degrees Fahrenheit
# The temperature 279 Degrees Kelvin converts to 42.52999999999997 Degrees Fahrenheit
# The temperature 263 Degrees Kelvin converts to 13.730000000000018 Degrees Fahrenheit
# The temperature 255 Degrees Kelvin converts to -0.6700000000000159 Degrees Fahrenheit
# The temperature 288 Degrees Kelvin converts to 58.72999999999996 Degrees Fahrenheit
# The temperature 250 Degrees Kelvin converts to -9.670000000000016 Degrees Fahrenheit
# The temperature 270 Degrees Kelvin converts to 26.329999999999984 Degrees Fahrenheit
# The temperature 292 Degrees Kelvin converts to 65.93 Degrees Fahrenheit

# %% [markdown]
# #### *Extra Challenge 2 solution:*

# %%
print("Initial Kelvin temperature list:  " + str(temps_k))
# Out:
# Initial Kelvin temperature list:  [248, 264, 243, 279, 263, 255, 288, 250, 270, 292]

# %%
# iterate over each element in the lenght of the list to replace each element with the fahrenheit conversion
for x in range(len(temps_k)):
    temps_k[x] = (temps_k[x] * (9/5)) - 459.67
print("Temperature list replaced with the fahrenheit conversion: " + str(temps_k))
# Out:
# Temperature list replaced with the fahrenheit conversion: [-13.269999999999982, 15.529999999999973, -22.269999999999982, 42.52999999999997, 13.730000000000018, -0.6700000000000159, 58.72999999999996, -9.670000000000016, 26.329999999999984, 65.93]

# %% [markdown]
# # COMPLETE
